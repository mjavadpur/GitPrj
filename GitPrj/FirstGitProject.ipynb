# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.name=mjavadpur
# user.email=mjavadpur@gmail.com

# %%
# !git config --global user.name "mjavadpur" 
# !git config --global user.email "mjavadpur@gmail.com"

# %%
TOKEN = "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"
USERNAME = "mjavadpur"
REPO = "GitPrj"

FILES_PATH = "/content/drive/MyDrive/Workshop/GitHub/"

# %%
# !git clone https://{TOKEN}@github.com/{USERNAME}/{REPO}
# Out:
# fatal: destination path 'GitPrj' already exists and is not an empty directory.

# %%
# %cd {REPO}
# Out:
# /content/GitPrj

# %%
# !cp -r FILES_PATH /content/
